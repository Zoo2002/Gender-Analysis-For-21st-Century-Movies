# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:142.0) Gecko/20100101 Firefox/142.0"}

# %%
movies=[]
for year in range(2000,2026):
  counter=0
  print(f'year:{year} - DONE')
  url=f'https://www.boxofficemojo.com/year/world/{year}/'
  response=requests.get(url, headers=headers)
  response.raise_for_status()
  html=response.text
  soup=BeautifulSoup(html, "html.parser")
  title_tags=soup.select("table a.a-link-normal")
  title_tags=title_tags[6:]
  for title_tag in title_tags:
    title=title_tag.get_text(strip=True)
    if title not in [movie['title'] for movie in movies]:
      movies.append({'year':year,'title':title})
      counter+=1
      if counter==120:
        break

# %%
movies_df=pd.DataFrame(movies)

# %%
movies_df
# Out:
#       year                               title
# 0     2000              Mission: Impossible II
# 1     2000                           Gladiator
# 2     2000                           Cast Away
# 3     2000                     What Women Want
# 4     2000                            Dinosaur
# ...    ...                                 ...
# 3115  2025               How to Make a Killing
# 3116  2025   About a Place in the Kinki Region
# 3117  2025  Doraemon: Nobita's Art World Tales
# 3118  2025                            Presence
# 3119  2025           Toy Story 2025 Re-release
#
# [3120 rows x 2 columns]

# %%
movies_df=pd.DataFrame({'ID': range(0,len(movies_df)), 'YEAR': movies_df['year'], 'TITLE': movies_df['title']})

# %%
movies_df
# Out:
#         ID  YEAR                               TITLE
# 0        0  2000              Mission: Impossible II
# 1        1  2000                           Gladiator
# 2        2  2000                           Cast Away
# 3        3  2000                     What Women Want
# 4        4  2000                            Dinosaur
# ...    ...   ...                                 ...
# 3115  3115  2025               How to Make a Killing
# 3116  3116  2025   About a Place in the Kinki Region
# 3117  3117  2025  Doraemon: Nobita's Art World Tales
# 3118  3118  2025                            Presence
# 3119  3119  2025           Toy Story 2025 Re-release
#
# [3120 rows x 3 columns]

# %%
movies_df.to_csv("/content/drive/MyDrive/PROJECT/movie_screenplay/base_movies_list.csv", index=False, encoding="utf-8")
